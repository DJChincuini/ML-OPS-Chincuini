# %%
import pandas as pd
from io import BytesIO
import gzip

# %%
with gzip.open(f'../datasets/users_item_comp.gz', 'rb') as archivo:
    contenido = archivo.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 with gzip.open(f'../datasets/users_item_comp.gz', 'rb') as archivo:
#       2     contenido = archivo.read()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2032.0_x64__qbz5n2kfra8p0\Lib\gzip.py:58, in open(filename, mode, compresslevel, encoding, errors, newline)
#      56 gz_mode = mode.replace("t", "")
#      57 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 58     binary_file = GzipFile(filename, gz_mode, compresslevel)
#      59 elif hasattr(filename, "read") or hasattr(filename, "write"):
#      60     binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# ...
